# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
file=pd.read_csv("By_Stock/By_Stock/Axis Development Bank Limited.csv")
file
# Out:
#           Date  No. Of Transaction  Max Price  Min Price  Closing Price  \
# 0   2013-05-02                12.0       80.0       74.0           74.0
# 1   2013-05-06                 1.0       73.0       73.0           73.0
# 2   2013-05-07                26.0       72.0       66.0           66.0
# 3   2013-05-08                42.0       68.0       65.0           66.0
# 4   2013-05-09                23.0       65.0       63.0           65.0
# ..         ...                 ...        ...        ...            ...
# 94  2013-10-01                10.0       78.0       76.0           78.0
# 95  2013-10-02                 9.0       80.0       77.0           79.0
# 96  2013-10-03                10.0       86.0       80.0           86.0
# 97  2013-10-06                43.0       94.0       87.0           94.0
# 98  2013-10-07                 6.0       93.0       91.0           91.0
#
#     Traded Shares    Amount  Previous Closing  Difference Rs.
# ...

# %%
df.columns
# Out:
# Index(['Date', 'No. Of Transaction', 'Max Price', 'Min Price', 'Closing Price',
#        'Traded Shares', 'Amount', 'Previous Closing', 'Difference Rs.'],
#       dtype='object')

# %%
file["Date"]=pd.to_datetime(file['Date'])

# %%
plt.plot(file["Date"],file[ 'No. Of Transaction'],color="blue",label="No. Of Transaction")
plt.plot(file["Date"],file['Closing Price'],color="yellow",label="Closing Price")
plt.plot(file["Date"],file['Traded Shares'],color="green",label="Trade Shares")
plt.plot(file["Date"],file['Amount'],color="orange",label="Amount")
plt.xlabel("Date")
plt.ylabel("value")
plt.title("Analysis of Market Transactions and Volum of Axis Development Bank Limited ")
plt.grid()
plt.xticks(rotation=90)
plt.tight_layout()
plt.legend()
plt.show()

# %%
bar_width=0.8
indices=np.arange(len(file["Date"]))
plt.bar(file["Date"],file[ 'No. Of Transaction'],color="blue",label="No. Of Transaction")
plt.bar(file["Date"],file['Traded Shares'],color="green",label="Trade Shares")
plt.bar(file["Date"],file['Amount'],color="orange",label="Amount")
plt.xlabel("Date")
plt.ylabel("value")
plt.title("Analysis of Market Transactions, Prices, and Volum of Axis Development Bank Limited ")
plt.grid()
plt.legend()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
file['Max Price Growth']=file['Max Price'].pct_change()*100
file['Closing Price Growth']=file['Closing Price'].pct_change()*100
plt.plot(file["Date"],file['Max Price Growth'],label="Max price growth",color="green")
plt.plot(file["Date"],file['Closing Price Growth'],label="Closing price growth",color="red")
plt.xlabel("Date")
plt.ylabel("growth (%)")
plt.legend()
plt.show()

# %%
corellation_matrix=file[['Max Price','Min Price','Closing Price','Traded Shares','Amount']].corr()
corellation_matrix
# Out:
#                Max Price  Min Price  Closing Price  Traded Shares    Amount
# Max Price       1.000000   0.969260       0.982825      -0.018937  0.074317
# Min Price       0.969260   1.000000       0.971076      -0.125079 -0.037079
# Closing Price   0.982825   0.971076       1.000000      -0.043638  0.053209
# Traded Shares  -0.018937  -0.125079      -0.043638       1.000000  0.989418
# Amount          0.074317  -0.037079       0.053209       0.989418  1.000000

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
sns.heatmap(corellation_matrix,annot=True,cmap="coolwarm")
plt.title("Corellation Matrix")
plt.show()
